# %%
import pandas as pd

# %%
df = pd.read_csv("raw/miplib_info.csv")

# %%
df
# Out:
#          InstanceInst. StatusStat.  VariablesVari.  BinariesBina.  \
# 0              10teams        easy          2025.0         1800.0
# 1                22433        easy           429.0          231.0
# 2                23588        easy           368.0          231.0
# 3     2club200v15p5scn        hard           200.0          200.0
# 4      30_70_45_05_100        easy         10772.0        10771.0
# ...                ...         ...             ...            ...
# 1060       woodlands09        hard        382147.0       382119.0
# 1061            xmas10        open          8100.0          900.0
# 1062          xmas10-2        open          8100.0          900.0
# 1063               z26        open         17937.0        17937.0
# 1064              zeil        open         70116.0         5314.0
#
#       IntegersInte.  ContinuousCont.  ConstraintsCons.  Nonz.Nonz.  \
# 0               0.0              225               230       12150
# 1               0.0              198               198        3408
# 2               0.0              137               137        3701
# 3               0.0                0             17013      104811
# 4               0.0                1             12050       45889
# ...             ...              ...               ...         ...
# 1060           28.0                0            194599     2646003
# 1061            0.0             7200              9080       43635
# 1062            0.0             7200              8184       35561
# 1063            0.0                0            850513     1715613
# 1064            0.0            64802             81558     1628941
#
#                 SubmitterSubm.   GroupGrou.      ObjectiveObje.  \
# 0       MIPLIB submission pool            –   923.9999999999997
# 1       MIPLIB submission pool            –               21477
# 2       MIPLIB submission pool            –   8089.999999999998
# 3     Balabhaskar Balasundaram            –                 -70
# 4                    J. Walser        30_70                   9
# ...                        ...          ...                 ...
# 1060            George Fonseca  timetabling                   0
# 1061               Simon Felix            –             -497.0*
# 1062               Simon Felix            –               -497*
# 1063          Daniel Bienstock            –            -1195.0*
# 1064           Andreas Bärmann            –  1086.261999999988*
#
#                                               TagsTags.
# 0     binary set_partitioning set_packing invariant_...
# 1                           mixed_binary general_linear
# 2                           mixed_binary general_linear
# 3              binary variable_bound invariant_knapsack
# 4     binary decomposition benchmark_suitable preced...
# ...                                                 ...
# 1060  aggregations variable_bound set_partitioning s...
# 1061  aggregations variable_bound cardinality invari...
# 1062  aggregations variable_bound cardinality invari...
# 1063                  binary variable_bound set_packing
# 1064             precedence variable_bound mixed_binary
#
# [1065 rows x 12 columns]

# %%
alex = pd.read_csv("raw/alexinstances.csv", sep=";")

# %%
alex["Name"]
# Out:
# 0               10teams
# 1                 23588
# 2               30n20b8
# 3                50v-10
# 4                a1c1s1
#              ...
# 327                umts
# 328    usAbbrv-8-25\_70
# 329                vpm1
# 330                vpm2
# 331           zib54-UUE
# Name: Name, Length: 332, dtype: object

# %%
name = alex[["Name"]]

# %%
name
# Out:
#                  Name
# 0             10teams
# 1               23588
# 2             30n20b8
# 3              50v-10
# 4              a1c1s1
# ..                ...
# 327              umts
# 328  usAbbrv-8-25\_70
# 329              vpm1
# 330              vpm2
# 331         zib54-UUE
#
# [332 rows x 1 columns]

# %%
name["Name"] = name["Name"].str.replace(r'\\_', '_', regex=True)
# Out:
# /var/folders/bs/06hvsvyd3tg0tg3r8dnfx4dm0000gn/T/ipykernel_2755/4149161653.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   name["Name"] = name["Name"].str.replace(r'\\_', '_', regex=True)

# %%
name
# Out:
#                 Name
# 0            10teams
# 1              23588
# 2            30n20b8
# 3             50v-10
# 4             a1c1s1
# ..               ...
# 327             umts
# 328  usAbbrv-8-25_70
# 329             vpm1
# 330             vpm2
# 331        zib54-UUE
#
# [332 rows x 1 columns]

# %%
df = df.rename(columns={'InstanceInst.':'Name'})

# %%
df
# Out:
#                   Name StatusStat.  VariablesVari.  BinariesBina.  \
# 0              10teams        easy          2025.0         1800.0
# 1                22433        easy           429.0          231.0
# 2                23588        easy           368.0          231.0
# 3     2club200v15p5scn        hard           200.0          200.0
# 4      30_70_45_05_100        easy         10772.0        10771.0
# ...                ...         ...             ...            ...
# 1060       woodlands09        hard        382147.0       382119.0
# 1061            xmas10        open          8100.0          900.0
# 1062          xmas10-2        open          8100.0          900.0
# 1063               z26        open         17937.0        17937.0
# 1064              zeil        open         70116.0         5314.0
#
#       IntegersInte.  ContinuousCont.  ConstraintsCons.  Nonz.Nonz.  \
# 0               0.0              225               230       12150
# 1               0.0              198               198        3408
# 2               0.0              137               137        3701
# 3               0.0                0             17013      104811
# 4               0.0                1             12050       45889
# ...             ...              ...               ...         ...
# 1060           28.0                0            194599     2646003
# 1061            0.0             7200              9080       43635
# 1062            0.0             7200              8184       35561
# 1063            0.0                0            850513     1715613
# 1064            0.0            64802             81558     1628941
#
#                 SubmitterSubm.   GroupGrou.      ObjectiveObje.  \
# 0       MIPLIB submission pool            –   923.9999999999997
# 1       MIPLIB submission pool            –               21477
# 2       MIPLIB submission pool            –   8089.999999999998
# 3     Balabhaskar Balasundaram            –                 -70
# 4                    J. Walser        30_70                   9
# ...                        ...          ...                 ...
# 1060            George Fonseca  timetabling                   0
# 1061               Simon Felix            –             -497.0*
# 1062               Simon Felix            –               -497*
# 1063          Daniel Bienstock            –            -1195.0*
# 1064           Andreas Bärmann            –  1086.261999999988*
#
#                                               TagsTags.
# 0     binary set_partitioning set_packing invariant_...
# 1                           mixed_binary general_linear
# 2                           mixed_binary general_linear
# 3              binary variable_bound invariant_knapsack
# 4     binary decomposition benchmark_suitable preced...
# ...                                                 ...
# 1060  aggregations variable_bound set_partitioning s...
# 1061  aggregations variable_bound cardinality invari...
# 1062  aggregations variable_bound cardinality invari...
# 1063                  binary variable_bound set_packing
# 1064             precedence variable_bound mixed_binary
#
# [1065 rows x 12 columns]

# %%
new = name.merge(df, on='Name', how='inner')

# %%
new
# Out:
#                 Name StatusStat.  VariablesVari.  BinariesBina.  \
# 0            10teams        easy          2025.0         1800.0
# 1              23588        easy           368.0          231.0
# 2            30n20b8        easy         18380.0        18318.0
# 3             50v-10        easy          2013.0         1464.0
# 4             a1c1s1        easy          3648.0          192.0
# ..               ...         ...             ...            ...
# 210          tr12-30        easy          1080.0          360.0
# 211   traininstance6        easy         10218.0         4154.0
# 212      uct-subprob        easy          2256.0          379.0
# 213             umts        easy          2947.0         2802.0
# 214  usAbbrv-8-25_70        hard          2312.0         1681.0
#
#      IntegersInte.  ContinuousCont.  ConstraintsCons.  Nonz.Nonz.  \
# 0              0.0              225               230       12150
# 1              0.0              137               137        3701
# 2             62.0                0               576      109706
# 3            183.0              366               233        2745
# 4              0.0             3456              3312       10178
# ..             ...              ...               ...         ...
# 210            0.0              720               750        2508
# 211         2056.0             4008             12309       32785
# 212            0.0             1877              1973       10147
# 213           72.0               73              4465       22872
# 214            0.0              631              3291        9628
#
#                           SubmitterSubm.     GroupGrou.     ObjectiveObje.  \
# 0                 MIPLIB submission pool              –  923.9999999999997
# 1                 MIPLIB submission pool              –  8089.999999999998
# 2    E. Coughlan, M. Lübbecke, J. Schulz              –                302
# 3                        Serge Bisaillon              –       3311.1799841
# 4                     M. Vyve, Y. Pochet           c1s1       11503.444125
# ..                                   ...            ...                ...
# 210               MIPLIB submission pool              –  130595.9999999999
# 211                           Gleb Belov  traininstance              28290
# 212                          Gerald Lach              –                314
# 213                              C. Polo              –  30090327.99999997
# 214                   publicly available              –                120
#
#                                              TagsTags.
# 0    binary set_partitioning set_packing invariant_...
# 1                          mixed_binary general_linear
# 2    benchmark benchmark_suitable precedence set_pa...
# 3    benchmark decomposition benchmark_suitable mix...
# 4    benchmark_suitable aggregations variable_bound...
# ..                                                 ...
# 210  benchmark decomposition benchmark_suitable agg...
# 211  benchmark benchmark_suitable aggregations prec...
# 212  benchmark benchmark_suitable aggregations vari...
# 213  decomposition benchmark_suitable aggregations ...
# 214  precedence invariant_knapsack knapsack mixed_b...
#
# [215 rows x 12 columns]

# %%
new.columns
# Out:
# Index(['Name', 'StatusStat.', 'VariablesVari.', 'BinariesBina.',
#        'IntegersInte.', 'ContinuousCont.', 'ConstraintsCons.', 'Nonz.Nonz.',
#        'SubmitterSubm.', 'GroupGrou.', 'ObjectiveObje.', 'TagsTags.'],
#       dtype='object')

# %%
new = new[['Name', 'StatusStat.', 'VariablesVari.', 'BinariesBina.',
       'IntegersInte.', 'ContinuousCont.', 'ConstraintsCons.', 'Nonz.Nonz.', 'ObjectiveObje.']]

# %%
new
# Out:
#                 Name StatusStat.  VariablesVari.  BinariesBina.  \
# 0            10teams        easy          2025.0         1800.0
# 1              23588        easy           368.0          231.0
# 2            30n20b8        easy         18380.0        18318.0
# 3             50v-10        easy          2013.0         1464.0
# 4             a1c1s1        easy          3648.0          192.0
# ..               ...         ...             ...            ...
# 210          tr12-30        easy          1080.0          360.0
# 211   traininstance6        easy         10218.0         4154.0
# 212      uct-subprob        easy          2256.0          379.0
# 213             umts        easy          2947.0         2802.0
# 214  usAbbrv-8-25_70        hard          2312.0         1681.0
#
#      IntegersInte.  ContinuousCont.  ConstraintsCons.  Nonz.Nonz.  \
# 0              0.0              225               230       12150
# 1              0.0              137               137        3701
# 2             62.0                0               576      109706
# 3            183.0              366               233        2745
# 4              0.0             3456              3312       10178
# ..             ...              ...               ...         ...
# 210            0.0              720               750        2508
# 211         2056.0             4008             12309       32785
# 212            0.0             1877              1973       10147
# 213           72.0               73              4465       22872
# 214            0.0              631              3291        9628
#
#         ObjectiveObje.
# 0    923.9999999999997
# 1    8089.999999999998
# 2                  302
# 3         3311.1799841
# 4         11503.444125
# ..                 ...
# 210  130595.9999999999
# 211              28290
# 212                314
# 213  30090327.99999997
# 214                120
#
# [215 rows x 9 columns]

# %%
mittelmann = pd.read_csv("raw/miplib_mittelmann.csv",sep = ";")

# %%
mittelmann
# Out:
#                    Name    Dual Bound  Primal Bound   Gap%     Nodes   Time  \
# 0                  ex10  1.000000e+02  1.000000e+02    0.0         0     68
# 1                   ex9  8.100000e+01  8.100000e+01    0.0         0      7
# 2                  leo1 -1.000000e+20  1.000000e+20     --         0  90397
# 3                  leo2 -1.000000e+20  1.000000e+20     --         0   8033
# 4               lotsize -1.000000e+20  1.000000e+20     --         0  11017
# ..                  ...           ...           ...    ...       ...    ...
# 235               mas74  1.180119e+04  1.180119e+04    0.0   7476416   1083
# 236          markshare2  0.000000e+00  1.600000e+01     --   9165191   7205
# 237                 mad  2.747659e-03  2.680000e-02  875.4  16217532   7205
# 238   neos-2657525-crna  0.000000e+00  8.280993e+00     --  19253157   7201
# 239  neos-3754480-nidda -1.151567e+05  1.303983e+04     --  43976038   7206
#
#       Status Solution
# 0         ok       ok
# 1         ok       ok
# 2      abort       --
# 3      abort       --
# 4      abort       --
# ..       ...      ...
# 235       ok       ok
# 236  stopped       ok
# 237  stopped       ok
# 238  stopped       ok
# 239  stopped       ok
#
# [240 rows x 8 columns]

# %%
new = new.merge(mittelmann, on='Name', how='inner')

# %%
new
# Out:
#                    Name StatusStat.  VariablesVari.  BinariesBina.  \
# 0               30n20b8        easy         18380.0        18318.0
# 1                50v-10        easy          2013.0         1464.0
# 2           assign1-5-8        easy           156.0          130.0
# 3                b1c1s1        easy          3872.0          288.0
# 4             beasleyC3        easy          2500.0         1250.0
# 5            binkar10_1        easy          2298.0          170.0
# 6              bnatt400        easy          3600.0         3600.0
# 7                cod105        easy          1024.0         1024.0
# 8           cost266-UUE        easy          4161.0          171.0
# 9             csched007        easy          1758.0         1457.0
# 10         cvs16r128-89        easy          3472.0         3472.0
# 11        exp-1-500-5-5        easy           990.0          250.0
# 12            gen-ip002        easy            41.0            0.0
# 13               glass4        easy           322.0          302.0
# 14            gmu-35-40        easy          1205.0         1200.0
# 15            gmu-35-50        easy          1919.0         1914.0
# 16     graph20-20-1rand        easy          2183.0         2183.0
# 17     graphdraw-domain        easy           254.0          180.0
# 18       ic97_potential        easy           728.0          450.0
# 19       icir97_tension        easy          2494.0          262.0
# 20              lotsize        easy          2985.0         1195.0
# 21                 mc11        easy          3040.0         1520.0
# 22              mcsched        easy          1747.0         1745.0
# 23      mik-250-20-75-4        easy           270.0           75.0
# 24   milo-v12-6-r2-40-1        easy          2688.0          840.0
# 25                 n5-3        easy          2550.0            0.0
# 26         neos-1582420        easy         10100.0        10000.0
# 27    neos-3024952-loue        easy          3255.0            0.0
# 28    neos-3046615-murg        easy           274.0          240.0
# 29    neos-3083819-nubu        easy          8644.0            0.0
# 30  neos-3216931-puriri        easy          3555.0         3268.0
# 31   neos-3381206-awhea        easy          2375.0          475.0
# 32   neos-3627168-kasai        easy          1462.0          535.0
# 33   neos-3754480-nidda        easy           253.0           50.0
# 34   neos-4387871-tavua        hard          4004.0         2000.0
# 35  neos-4954672-berkel        easy          1533.0          630.0
# 36          neos-911970        easy           888.0          840.0
# 37               neos17        easy           535.0          300.0
# 38                neos5        easy            63.0           53.0
# 39            ns1208400        easy          2883.0         2880.0
# 40            ns1830653        easy          1629.0         1458.0
# 41            nu25-pr12        easy          5868.0         5832.0
# 42           p200x1188c        easy          2376.0         1188.0
# 43               pg5_34        easy          2600.0          100.0
# 44                   pg        easy          2700.0          100.0
# 45      ran14x18-disj-8        easy           504.0          252.0
# 46           reblock115        easy          1150.0         1150.0
# 47     rococoB10-011000        easy          4456.0         4320.0
# 48     rococoC10-001000        easy          3117.0         2993.0
# 49             roll3000        easy          1166.0          246.0
# 50             seymour1        easy          1372.0          451.0
# 51              seymour        easy          1372.0         1372.0
# 52           sp150x300d        easy           600.0          300.0
# 53        supportcase26        easy           436.0          396.0
# 54              timtab1        easy           397.0           77.0
# 55              tr12-30        easy          1080.0          360.0
# 56       traininstance6        easy         10218.0         4154.0
# 57          uct-subprob        easy          2256.0          379.0
#
#     IntegersInte.  ContinuousCont.  ConstraintsCons.  Nonz.Nonz.  \
# 0            62.0                0               576      109706
# 1           183.0              366               233        2745
# 2             0.0               26               161        3720
# 3             0.0             3584              3904       11408
# 4             0.0             1250              1750        5000
# 5             0.0             2128              1026        4496
# 6             0.0                0              5614       21698
# 7             0.0                0              1024       57344
# 8             0.0             3990              1446       12312
# 9             0.0              301               351        6379
# 10            0.0                0              4633       12528
# 11            0.0              740               550        1980
# 12           41.0                0                24         922
# 13            0.0               20               396        1815
# 14            0.0                5               424        4843
# 15            0.0                5               435        8643
# 16            0.0                0              5587       19277
# 17           20.0               54               865        2600
# 18           73.0              205              1046        3138
# 19          573.0             1659              1203       22333
# 20            0.0             1790              1920        6565
# 21            0.0             1520              1920        6080
# 22            0.0                2              2107        8088
# 23          175.0               20               195        9270
# 24            0.0             1848              5628       14604
# 25          150.0             2400              1062        9900
# 26          100.0                0             10180       24814
# 27         3255.0                0              3705       17310
# 28           16.0               18               498        1266
# 29         8644.0                0              4725       24048
# 30            0.0              287              5989       91691
# 31         1900.0                0               479        4275
# 32            0.0              927              1655        5158
# 33            0.0              203               402        1488
# 34            0.0             2004              4554       23496
# 35            0.0              903              1848        8007
# 36            0.0               48               107        3408
# 37            0.0              235               486        4931
# 38            0.0               10                63        2016
# 39            0.0                3              4289       81746
# 40            0.0              171              2932      100933
# 41           36.0                0              2313       17712
# 42            0.0             1188              1388        4752
# 43            0.0             2500               225        7700
# 44            0.0             2600               125        5200
# 45            0.0              252               447       10277
# 46            0.0                0              4735       13724
# 47          136.0                0              1667       16517
# 48          124.0                0              1293       11751
# 49          492.0              428              2295       29386
# 50            0.0              921              4944       33549
# 51            0.0                0              4944       33549
# 52            0.0              300               450        1200
# 53            0.0               40               870        2492
# 54           94.0              226               171         829
# 55            0.0              720               750        2508
# 56         2056.0             4008             12309       32785
# 57            0.0             1877              1973       10147
#
#        ObjectiveObje.    Dual Bound  Primal Bound   Gap%     Nodes   Time  \
# 0                 302  3.020000e+02  3.020000e+02    0.0      2053    150
# 1        3311.1799841  3.268506e+03  3.313180e+03    1.4   1104554   7201
# 2    211.999999999998  2.034468e+02  2.120000e+02    4.2   6192038   7202
# 3            24544.25  2.156668e+04  2.476876e+04   14.8     59282   7200
# 4   753.9999999999128  7.540000e+02  7.540000e+02    0.0         1     12
# 5        6742.1998835  6.742200e+03  6.742200e+03    0.0      1829     17
# 6                   1  1.000000e+00  1.000000e+00    0.0      6537    151
# 7                 -12 -1.200000e+01 -1.200000e+01    0.0         3     42
# 8   25148940.55999998  2.514894e+07  2.514894e+07    0.0    273638   2834
# 9   350.9999999999955  3.510000e+02  3.510000e+02    0.0     92266   1508
# 10                -97 -1.135335e+02 -9.600000e+01   18.3     16433   7200
# 11              65887  6.588700e+04  6.588700e+04    0.0         1      2
# 12       -4783.733392 -4.783733e+03 -4.783733e+03    0.0   5453901    658
# 13  1200012599.972384  1.200013e+09  1.200013e+09    0.0    153562    242
# 14      -2406733.3688 -2.406886e+06 -2.406481e+06    0.0   4371395   7207
# 15        -2607958.33 -2.608070e+06 -2.607266e+06    0.0   1542703   7205
# 16                 -9 -9.000000e+00 -9.000000e+00    0.0       259      3
# 17  19685.99997550038  1.968600e+04  1.968600e+04    0.0   2462573    783
# 18   3941.99993090225  3.935922e+03  3.942000e+03    0.2   1923860   7200
# 19               6375  6.375000e+03  6.375000e+03    0.0   1461563   4040
# 20            1480195 -1.000000e+20  1.000000e+20     --         0  11017
# 21  11688.99999999966  1.168900e+04  1.168900e+04    0.0         5     20
# 22             211913  2.119130e+05  2.119130e+05    0.0      9535    217
# 23             -52301 -5.230100e+04 -5.230100e+04    0.0     17927     36
# 24    326481.14282799  3.264811e+05  3.264811e+05    0.0    412157   4302
# 25  8104.999999993999  8.105000e+03  8.105000e+03    0.0      1874     40
# 26  90.99999999999996  9.100000e+01  9.100000e+01    0.0        43     13
# 27              26756  2.672810e+04  2.676600e+04    0.1    201171   7201
# 28               1600  5.877763e+02  1.604000e+03  172.9   5276774   7206
# 29            6307996  6.307996e+06  6.307996e+06    0.0      1385     10
# 30              71320  7.132000e+04  7.132000e+04    0.0      2667   3473
# 31                453  4.530000e+02  4.530000e+02    0.0         1      1
# 32  988585.6199999998  9.885856e+05  9.885856e+05    0.0    247215    295
# 33  12941.73838561778 -1.151567e+05  1.303983e+04     --  43976038   7206
# 34       33.384729927  2.999651e+01  3.338473e+01   11.3     26031   7200
# 35            2612710  2.388634e+06  2.622548e+06    9.8    402011   7202
# 36              54.76  5.476000e+01  5.476000e+01    0.0      1187     14
# 37       0.1500025774  1.500026e-01  1.500026e-01    0.0      2298      4
# 38                 15  1.500000e+01  1.500000e+01    0.0   2437610    558
# 39                  2  2.000000e+00  2.000000e+00    0.0      2049    465
# 40              20622  2.062200e+04  2.062200e+04    0.0      6269    146
# 41  53904.99999999999  5.390500e+04  5.390500e+04    0.0        65      4
# 42              15078  1.507800e+04  1.507800e+04    0.0         1      2
# 43       -14339.35345 -1.433935e+04 -1.433935e+04    0.0    180891   4360
# 44     -8674.34260712 -8.674343e+03 -8.674343e+03    0.0       727     22
# 45               3712  3.712000e+03  3.712000e+03    0.0    291502    862
# 46     -36800603.2332 -3.680060e+07 -3.680060e+07    0.0    618898   3712
# 47              19449  1.742416e+04  1.944900e+04   11.6    182105   7200
# 48              11460  1.146000e+04  1.146000e+04    0.0     45738    633
# 49       12889.999992  1.289000e+04  1.289000e+04    0.0      1200     20
# 50       410.76370139  4.107637e+02  4.107637e+02    0.0      1370     45
# 51                423  4.201979e+02  4.230000e+02    0.7    296800   7200
# 52                 69  6.900000e+01  6.900000e+01    0.0       677      1
# 53        1745.123813  1.655650e+03  1.745124e+03    5.4   3914568   7202
# 54    764771.99999978  7.647720e+05  7.647720e+05    0.0     26692     52
# 55  130595.9999999999  1.305960e+05  1.305960e+05    0.0    345154    400
# 56              28290  2.829000e+04  2.829000e+04    0.0    468118    987
# 57                314  3.140000e+02  3.140000e+02    0.0     47598   1227
#
#      Status Solution
# 0        ok       ok
# 1   stopped       ok
# 2   stopped       ok
# 3   stopped       ok
# 4        ok       ok
# 5        ok       ok
# 6        ok       ok
# 7        ok       ok
# 8        ok       ok
# 9        ok       ok
# 10  stopped       ok
# 11       ok       ok
# 12       ok       ok
# 13       ok       ok
# 14  stopped       ok
# 15  stopped       ok
# 16       ok       ok
# 17       ok       ok
# 18  stopped       ok
# 19       ok       ok
# 20    abort       --
# 21       ok       ok
# 22       ok       ok
# 23       ok       ok
# 24       ok       ok
# 25       ok       ok
# 26       ok       ok
# 27  stopped       ok
# 28  stopped       ok
# 29       ok       ok
# 30       ok       ok
# 31       ok       ok
# 32       ok       ok
# 33  stopped       ok
# 34  stopped       ok
# 35  stopped       ok
# 36       ok       ok
# 37       ok       ok
# 38       ok       ok
# 39       ok       ok
# 40       ok       ok
# 41       ok       ok
# 42       ok       ok
# 43       ok       ok
# 44       ok       ok
# 45       ok       ok
# 46       ok       ok
# 47  stopped       ok
# 48       ok       ok
# 49       ok       ok
# 50       ok       ok
# 51  stopped       ok
# 52       ok       ok
# 53  stopped       ok
# 54       ok       ok
# 55       ok       ok
# 56       ok       ok
# 57       ok       ok

# %%
new = new[(new.Status != "stopped") & (new.Nodes > 0)]

# %%
new.to_csv('miplib_full.csv', index=False)

# %%
new[new.Status != "stopped"]
# Out:
#                    Name StatusStat.  VariablesVari.  BinariesBina.  \
# 0               30n20b8        easy         18380.0        18318.0
# 4             beasleyC3        easy          2500.0         1250.0
# 5            binkar10_1        easy          2298.0          170.0
# 6              bnatt400        easy          3600.0         3600.0
# 7                cod105        easy          1024.0         1024.0
# 8           cost266-UUE        easy          4161.0          171.0
# 9             csched007        easy          1758.0         1457.0
# 11        exp-1-500-5-5        easy           990.0          250.0
# 12            gen-ip002        easy            41.0            0.0
# 13               glass4        easy           322.0          302.0
# 16     graph20-20-1rand        easy          2183.0         2183.0
# 17     graphdraw-domain        easy           254.0          180.0
# 19       icir97_tension        easy          2494.0          262.0
# 21                 mc11        easy          3040.0         1520.0
# 22              mcsched        easy          1747.0         1745.0
# 23      mik-250-20-75-4        easy           270.0           75.0
# 24   milo-v12-6-r2-40-1        easy          2688.0          840.0
# 25                 n5-3        easy          2550.0            0.0
# 26         neos-1582420        easy         10100.0        10000.0
# 29    neos-3083819-nubu        easy          8644.0            0.0
# 30  neos-3216931-puriri        easy          3555.0         3268.0
# 31   neos-3381206-awhea        easy          2375.0          475.0
# 32   neos-3627168-kasai        easy          1462.0          535.0
# 36          neos-911970        easy           888.0          840.0
# 37               neos17        easy           535.0          300.0
# 38                neos5        easy            63.0           53.0
# 39            ns1208400        easy          2883.0         2880.0
# 40            ns1830653        easy          1629.0         1458.0
# 41            nu25-pr12        easy          5868.0         5832.0
# 42           p200x1188c        easy          2376.0         1188.0
# 43               pg5_34        easy          2600.0          100.0
# 44                   pg        easy          2700.0          100.0
# 45      ran14x18-disj-8        easy           504.0          252.0
# 46           reblock115        easy          1150.0         1150.0
# 48     rococoC10-001000        easy          3117.0         2993.0
# 49             roll3000        easy          1166.0          246.0
# 50             seymour1        easy          1372.0          451.0
# 52           sp150x300d        easy           600.0          300.0
# 54              timtab1        easy           397.0           77.0
# 55              tr12-30        easy          1080.0          360.0
# 56       traininstance6        easy         10218.0         4154.0
# 57          uct-subprob        easy          2256.0          379.0
#
#     IntegersInte.  ContinuousCont.  ConstraintsCons.  Nonz.Nonz.  \
# 0            62.0                0               576      109706
# 4             0.0             1250              1750        5000
# 5             0.0             2128              1026        4496
# 6             0.0                0              5614       21698
# 7             0.0                0              1024       57344
# 8             0.0             3990              1446       12312
# 9             0.0              301               351        6379
# 11            0.0              740               550        1980
# 12           41.0                0                24         922
# 13            0.0               20               396        1815
# 16            0.0                0              5587       19277
# 17           20.0               54               865        2600
# 19          573.0             1659              1203       22333
# 21            0.0             1520              1920        6080
# 22            0.0                2              2107        8088
# 23          175.0               20               195        9270
# 24            0.0             1848              5628       14604
# 25          150.0             2400              1062        9900
# 26          100.0                0             10180       24814
# 29         8644.0                0              4725       24048
# 30            0.0              287              5989       91691
# 31         1900.0                0               479        4275
# 32            0.0              927              1655        5158
# 36            0.0               48               107        3408
# 37            0.0              235               486        4931
# 38            0.0               10                63        2016
# 39            0.0                3              4289       81746
# 40            0.0              171              2932      100933
# 41           36.0                0              2313       17712
# 42            0.0             1188              1388        4752
# 43            0.0             2500               225        7700
# 44            0.0             2600               125        5200
# 45            0.0              252               447       10277
# 46            0.0                0              4735       13724
# 48          124.0                0              1293       11751
# 49          492.0              428              2295       29386
# 50            0.0              921              4944       33549
# 52            0.0              300               450        1200
# 54           94.0              226               171         829
# 55            0.0              720               750        2508
# 56         2056.0             4008             12309       32785
# 57            0.0             1877              1973       10147
#
#        ObjectiveObje.    Dual Bound  Primal Bound Gap%    Nodes  Time Status  \
# 0                 302  3.020000e+02  3.020000e+02  0.0     2053   150     ok
# 4   753.9999999999128  7.540000e+02  7.540000e+02  0.0        1    12     ok
# 5        6742.1998835  6.742200e+03  6.742200e+03  0.0     1829    17     ok
# 6                   1  1.000000e+00  1.000000e+00  0.0     6537   151     ok
# 7                 -12 -1.200000e+01 -1.200000e+01  0.0        3    42     ok
# 8   25148940.55999998  2.514894e+07  2.514894e+07  0.0   273638  2834     ok
# 9   350.9999999999955  3.510000e+02  3.510000e+02  0.0    92266  1508     ok
# 11              65887  6.588700e+04  6.588700e+04  0.0        1     2     ok
# 12       -4783.733392 -4.783733e+03 -4.783733e+03  0.0  5453901   658     ok
# 13  1200012599.972384  1.200013e+09  1.200013e+09  0.0   153562   242     ok
# 16                 -9 -9.000000e+00 -9.000000e+00  0.0      259     3     ok
# 17  19685.99997550038  1.968600e+04  1.968600e+04  0.0  2462573   783     ok
# 19               6375  6.375000e+03  6.375000e+03  0.0  1461563  4040     ok
# 21  11688.99999999966  1.168900e+04  1.168900e+04  0.0        5    20     ok
# 22             211913  2.119130e+05  2.119130e+05  0.0     9535   217     ok
# 23             -52301 -5.230100e+04 -5.230100e+04  0.0    17927    36     ok
# 24    326481.14282799  3.264811e+05  3.264811e+05  0.0   412157  4302     ok
# 25  8104.999999993999  8.105000e+03  8.105000e+03  0.0     1874    40     ok
# 26  90.99999999999996  9.100000e+01  9.100000e+01  0.0       43    13     ok
# 29            6307996  6.307996e+06  6.307996e+06  0.0     1385    10     ok
# 30              71320  7.132000e+04  7.132000e+04  0.0     2667  3473     ok
# 31                453  4.530000e+02  4.530000e+02  0.0        1     1     ok
# 32  988585.6199999998  9.885856e+05  9.885856e+05  0.0   247215   295     ok
# 36              54.76  5.476000e+01  5.476000e+01  0.0     1187    14     ok
# 37       0.1500025774  1.500026e-01  1.500026e-01  0.0     2298     4     ok
# 38                 15  1.500000e+01  1.500000e+01  0.0  2437610   558     ok
# 39                  2  2.000000e+00  2.000000e+00  0.0     2049   465     ok
# 40              20622  2.062200e+04  2.062200e+04  0.0     6269   146     ok
# 41  53904.99999999999  5.390500e+04  5.390500e+04  0.0       65     4     ok
# 42              15078  1.507800e+04  1.507800e+04  0.0        1     2     ok
# 43       -14339.35345 -1.433935e+04 -1.433935e+04  0.0   180891  4360     ok
# 44     -8674.34260712 -8.674343e+03 -8.674343e+03  0.0      727    22     ok
# 45               3712  3.712000e+03  3.712000e+03  0.0   291502   862     ok
# 46     -36800603.2332 -3.680060e+07 -3.680060e+07  0.0   618898  3712     ok
# 48              11460  1.146000e+04  1.146000e+04  0.0    45738   633     ok
# 49       12889.999992  1.289000e+04  1.289000e+04  0.0     1200    20     ok
# 50       410.76370139  4.107637e+02  4.107637e+02  0.0     1370    45     ok
# 52                 69  6.900000e+01  6.900000e+01  0.0      677     1     ok
# 54    764771.99999978  7.647720e+05  7.647720e+05  0.0    26692    52     ok
# 55  130595.9999999999  1.305960e+05  1.305960e+05  0.0   345154   400     ok
# 56              28290  2.829000e+04  2.829000e+04  0.0   468118   987     ok
# 57                314  3.140000e+02  3.140000e+02  0.0    47598  1227     ok
#
#    Solution
# 0        ok
# 4        ok
# 5        ok
# 6        ok
# 7        ok
# 8        ok
# 9        ok
# 11       ok
# 12       ok
# 13       ok
# 16       ok
# 17       ok
# 19       ok
# 21       ok
# 22       ok
# 23       ok
# 24       ok
# 25       ok
# 26       ok
# 29       ok
# 30       ok
# 31       ok
# 32       ok
# 36       ok
# 37       ok
# 38       ok
# 39       ok
# 40       ok
# 41       ok
# 42       ok
# 43       ok
# 44       ok
# 45       ok
# 46       ok
# 48       ok
# 49       ok
# 50       ok
# 52       ok
# 54       ok
# 55       ok
# 56       ok
# 57       ok

# %%
with open('instances_set.txt', 'w') as file:
    for name in new["Name"]:
        file.write(name + '\n')
