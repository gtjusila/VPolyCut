# %%
import os
import pandas as pd

def extract_folder_info(folder_name):
    """Extract TIME and INSTANCE from the folder name."""
    try:
        first_underscore = folder_name.index('_')
        last_underscore = folder_name.rindex('_')
        TIME = folder_name[:first_underscore]
        INSTANCE = folder_name[first_underscore + 1:last_underscore]
        return TIME, INSTANCE
    except ValueError:
        return None, None

def extract_gap(result_file_path):
    """Extract GAP value from results.txt file."""
    GAP = 0
    if os.path.exists(result_file_path):
        try:
            with open(result_file_path, 'r') as result_file:
                for line in result_file:
                    if line.startswith("GapClosed:"):
                        GAP = float(line.split(':')[1].strip())
                        break
        except Exception as e:
            print(f"Error reading {result_file_path}: {e}")
    return GAP

def extract_feasibility(result_file_path):
    """Extract feasibility information from results.txt file."""
    feasibility = "false"  # Default value if line is not found
    if os.path.exists(result_file_path):
        try:
            with open(result_file_path, 'r') as result_file:
                for line in result_file:
                    if line.startswith("DbgSolFeasible:"):
                        feasibility = line.split(':')[1].strip().lower()
                        break
        except Exception as e:
            print(f"Error reading {result_file_path}: {e}")
    return feasibility

def extract_solving_time(solving_stat_file_path):
    """Extract SOLVING_TIME value from solving_statistic.txt file."""
    SOLVING_TIME = 3700
    if os.path.exists(solving_stat_file_path):
        try:
            with open(solving_stat_file_path, 'r') as solving_stat_file:
                for line in solving_stat_file:
                    if line.startswith("Total Time"):
                        SOLVING_TIME = float(line.split(':')[1].strip())
                        break
        except Exception as e:
            print(f"Error reading {solving_stat_file_path}: {e}")
    return SOLVING_TIME

def process_folder(folder_path, folder_name, mode):
    """Process each folder to extract required information."""
    TIME, INSTANCE = extract_folder_info(folder_name)
    if TIME is None or INSTANCE is None:
        return None

    result_file_path = os.path.join(folder_path, 'results.txt')
    solving_stat_file_path = os.path.join(folder_path, 'solving_statistic.txt')

    GAP = extract_gap(result_file_path)
    FEASIBILITY = extract_feasibility(result_file_path)
    SOLVING_TIME = extract_solving_time(solving_stat_file_path)

    return [INSTANCE, mode, GAP, SOLVING_TIME, FEASIBILITY]

def fetchresult(main_dir, modes):
    """Main function to iterate through directories and collect data."""
    data = []

    for mode in os.listdir(main_dir):
        if mode not in modes: continue
        mode_path = os.path.join(main_dir, mode)
        if os.path.isdir(mode_path):
            for folder_name in os.listdir(mode_path):
                folder_path = os.path.join(mode_path, folder_name)
                if os.path.isdir(folder_path):
                    folder_data = process_folder(folder_path, folder_name, mode)
                    if folder_data:
                        data.append(folder_data)

    df = pd.DataFrame(data, columns=['INSTANCE', 'MODE', 'GAP', 'TIME','FEASIBILITY'])
    return df

# %%
main_dir = os.path.join(os.getcwd(), 'Data')
df = fetchresult(main_dir,["gomory","vpc"])
df
# Out:
#                 INSTANCE         MODE       GAP     TIME FEASIBILITY
# 0    neos-3216931-puriri  vpcwsubscip  0.000000  3700.00       false
# 1           neos-1582420  vpcwsubscip  0.000000  3700.00       false
# 2         icir97_tension  vpcwsubscip  0.037497   617.66       false
# 3       graph20-20-1rand  vpcwsubscip  0.000000  2813.45       false
# 4        ran14x18-disj-8  vpcwsubscip  0.000000  3700.00       false
# ..                   ...          ...       ...      ...         ...
# 121            gen-ip002          vpc  0.009065     0.17        true
# 122               cod105          vpc  0.004376   165.90        true
# 123            nu25-pr12          vpc  0.044327   222.17        true
# 124       icir97_tension          vpc  0.201517   263.58       false
# 125          uct-subprob          vpc  0.014709  3029.15        true
#
# [126 rows x 5 columns]

# %%
df[['INSTANCE', 'MODE']].drop_duplicates()
# Out:
#                 INSTANCE         MODE
# 0    neos-3216931-puriri  vpcwsubscip
# 1           neos-1582420  vpcwsubscip
# 2         icir97_tension  vpcwsubscip
# 3       graph20-20-1rand  vpcwsubscip
# 4        ran14x18-disj-8  vpcwsubscip
# ..                   ...          ...
# 121            gen-ip002          vpc
# 122               cod105          vpc
# 123            nu25-pr12          vpc
# 124       icir97_tension          vpc
# 125          uct-subprob          vpc
#
# [126 rows x 2 columns]

# %%
# Pivot the DataFrame to the desired format
df_pivot = df.pivot(index='INSTANCE', columns='MODE', values=['GAP', 'TIME','FEASIBILITY'])

# Flatten the multi-level columns
df_pivot.columns = ['_'.join(col).strip() for col in df_pivot.columns.values]

gap_columns = [col for col in df_pivot.columns if 'GAP' in col]
df_pivot[gap_columns] = df_pivot[gap_columns].apply(lambda x: round(x * 100, 2))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'float' object has no attribute 'rint'
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 8
#       5 df_pivot.columns = ['_'.join(col).strip() for col in df_pivot.columns.values]
#       7 gap_columns = [col for col in df_pivot.columns if 'GAP' in col]
# ----> 8 df_pivot[gap_columns] = df_pivot[gap_columns].apply(lambda x: round(x * 100, 2))
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:9423, in DataFrame.apply(self, func, axis, raw, result_type, args, **kwargs)
#    9412 from pandas.core.apply import frame_apply
#    9414 op = frame_apply(
#    9415     self,
#    9416     func=func,
#    (...)
#    9421     kwargs=kwargs,
#    9422 )
# -> 9423 return op.apply().__finalize__(self, method="apply")
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:678, in FrameApply.apply(self)
#     675 elif self.raw:
#     676     return self.apply_raw()
# --> 678 return self.apply_standard()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:798, in FrameApply.apply_standard(self)
#     797 def apply_standard(self):
# --> 798     results, res_index = self.apply_series_generator()
#     800     # wrap results
#     801     return self.wrap_results(results, res_index)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/apply.py:814, in FrameApply.apply_series_generator(self)
#     811 with option_context("mode.chained_assignment", None):
#     812     for i, v in enumerate(series_gen):
#     813         # ignore SettingWithCopy here in case the user mutates
# --> 814         results[i] = self.f(v)
#     815         if isinstance(results[i], ABCSeries):
#     816             # If we have a view on v, we need to make a copy because
#     817             #  series_generator will swap out the underlying data
#     818             results[i] = results[i].copy(deep=False)
#
# Cell In[21], line 8, in <lambda>(x)
#       5 df_pivot.columns = ['_'.join(col).strip() for col in df_pivot.columns.values]
#       7 gap_columns = [col for col in df_pivot.columns if 'GAP' in col]
# ----> 8 df_pivot[gap_columns] = df_pivot[gap_columns].apply(lambda x: round(x * 100, 2))
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:1597, in NDFrame.__round__(self, decimals)
#    1595 @final
#    1596 def __round__(self: NDFrameT, decimals: int = 0) -> NDFrameT:
# -> 1597     return self.round(decimals).__finalize__(self, method="__round__")
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:2569, in Series.round(self, decimals, *args, **kwargs)
#    2537 """
#    2538 Round each value in a Series to the given number of decimals.
#    2539
#    (...)
#    2566 dtype: float64
#    2567 """
#    2568 nv.validate_round(args, kwargs)
# -> 2569 result = self._values.round(decimals)
#    2570 result = self._constructor(result, index=self.index, copy=False).__finalize__(
#    2571     self, method="round"
#    2572 )
#    2574 return result
#
# TypeError: loop of ufunc does not support argument 0 of type float which has no callable rint method

# %%
df_pivot
# Out:
#                     GAP_gomory   GAP_vpc GAP_vpcwsubscip TIME_gomory TIME_vpc  \
# INSTANCE
# 30n20b8               0.096826       0.0             0.0       29.19  3669.05
# beasleyC3             0.011796  0.011796        0.281123        0.08   131.38
# binkar10_1            0.067593  0.066913        0.062727        0.09    41.79
# bnatt400                   0.0       0.0             0.0        1.94  3558.22
# cod105                0.008656  0.004376             0.0        4.26    165.9
# cost266-UUE           0.272712  0.186341        0.211037        0.37   300.45
# csched007             0.089249  0.033897        0.003228        0.27   237.61
# exp-1-500-5-5         0.231601  0.217312        0.217312        0.06    36.89
# gen-ip002             0.021483  0.009065        0.004108        0.01     0.17
# glass4                     0.0      -0.0             0.0        0.04     2.72
# graph20-20-1rand           0.0       0.0             0.0        0.39     4.63
# graphdraw-domain      0.001149       0.0             0.0        0.12     2.71
# icir97_tension        0.201517  0.201517        0.037497        0.48   263.58
# mc11                  0.004638  0.007964        0.005085        0.11  1042.45
# mcsched               0.000408       0.0             0.0        1.03   3700.0
# mik-250-20-75-4         0.5383  0.532846        0.532846        0.04     3.34
# milo-v12-6-r2-40-1         0.0       0.0             0.0        0.56   3700.0
# n5-3                  0.152517  0.132047        0.313609        0.14    50.13
# neos-1582420          0.053285  0.018452             0.0        2.42  2411.69
# neos-3083819-nubu     0.423671  0.002312        0.010334        0.42   125.92
# neos-3216931-puriri   0.016841       0.0             0.0       41.28   3700.0
# neos-3381206-awhea         0.0       0.0             0.0        0.17   617.87
# neos-3627168-kasai     0.14211   0.14211         0.00351        0.15   154.95
# neos-911970                0.0       0.0             0.0        0.14    16.53
# neos17                0.000005       0.0        0.001965        0.09      0.1
# neos5                 0.115741  0.083333        0.083333        0.02     0.42
# ns1208400                  0.0       0.0             0.0        2.38  2948.39
# ns1830653             0.143007  0.022232             0.0        1.15    97.16
# nu25-pr12              0.52577  0.044327        0.319826        0.42   222.17
# p200x1188c            0.004474  0.004762        0.004762        0.06     6.79
# pg                    0.242918  0.242988        0.242988        0.07   175.34
# pg5_34                0.234496  0.234496        0.234496        0.08   154.43
# ran14x18-disj-8       0.002779  0.001327             0.0        0.18    41.18
# reblock115            0.071661   0.09966        0.126451         2.5  2885.68
# rococoC10-001000      0.290088  0.145329        0.025699        0.32   379.63
# roll3000              0.121388  0.002481        0.000323        0.56    96.28
# seymour1              0.134667  0.134657        0.116899        1.14   330.95
# sp150x300d            0.014664  0.010978        0.158675        0.03     2.61
# timtab1               0.125563  0.112441        0.177796        0.03     2.34
# tr12-30               -3.01546  -2.84793        -4.93647        0.08    98.55
# traininstance6             0.0       0.0             0.0        5.22   232.84
# uct-subprob           0.014801  0.014709        0.009823        1.13  3029.15
#
#                     TIME_vpcwsubscip FEASIBILITY_gomory FEASIBILITY_vpc  \
# INSTANCE
# 30n20b8                      4414.77              false           false
# beasleyC3                     241.77               true            true
# binkar10_1                    204.52              false           false
# bnatt400                      3700.0               true            true
# cod105                        3700.0               true            true
# cost266-UUE                   143.49               true            true
# csched007                     470.88              false           false
# exp-1-500-5-5                  28.21               true            true
# gen-ip002                       4.42               true            true
# glass4                          6.46              false           false
# graph20-20-1rand             2813.45              false           false
# graphdraw-domain                8.71               true            true
# icir97_tension                617.66              false           false
# mc11                          932.84               true            true
# mcsched                       3700.0              false           false
# mik-250-20-75-4                 7.45               true            true
# milo-v12-6-r2-40-1            3700.0              false           false
# n5-3                           48.86               true            true
# neos-1582420                  3700.0               true            true
# neos-3083819-nubu            1350.41              false           false
# neos-3216931-puriri           3700.0              false           false
# neos-3381206-awhea           1186.53               true            true
# neos-3627168-kasai            137.74              false           false
# neos-911970                    37.63               true            true
# neos17                         21.69              false           false
# neos5                           5.24               true            true
# ns1208400                     3700.0              false           false
# ns1830653                     488.48               true            true
# nu25-pr12                      177.4               true            true
# p200x1188c                      7.82               true            true
# pg                             86.09              false           false
# pg5_34                         80.72               true            true
# ran14x18-disj-8               3700.0               true            true
# reblock115                   1034.92               true            true
# rococoC10-001000              692.32              false           false
# roll3000                       472.2              false           false
# seymour1                     1065.12               true            true
# sp150x300d                      8.44              false           false
# timtab1                        10.13              false           false
# tr12-30                        91.11              false           false
# traininstance6                3700.0              false           false
# uct-subprob                  1078.78               true            true
#
#                     FEASIBILITY_vpcwsubscip
# INSTANCE
# 30n20b8                               false
# beasleyC3                             false
# binkar10_1                            false
# bnatt400                              false
# cod105                                false
# cost266-UUE                           false
# csched007                             false
# exp-1-500-5-5                         false
# gen-ip002                             false
# glass4                                false
# graph20-20-1rand                      false
# graphdraw-domain                      false
# icir97_tension                        false
# mc11                                  false
# mcsched                               false
# mik-250-20-75-4                       false
# milo-v12-6-r2-40-1                    false
# n5-3                                  false
# neos-1582420                          false
# neos-3083819-nubu                     false
# neos-3216931-puriri                   false
# neos-3381206-awhea                    false
# neos-3627168-kasai                    false
# neos-911970                           false
# neos17                                false
# neos5                                 false
# ns1208400                             false
# ns1830653                             false
# nu25-pr12                             false
# p200x1188c                            false
# pg                                    false
# pg5_34                                false
# ran14x18-disj-8                       false
# reblock115                            false
# rococoC10-001000                      false
# roll3000                              false
# seymour1                              false
# sp150x300d                            false
# timtab1                               false
# tr12-30                               false
# traininstance6                        false
# uct-subprob                           false

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3653, in Index.get_loc(self, key)
#    3652 try:
# -> 3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:147, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/_libs/index.pyx:176, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gomory_gap'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 2
#       1 df_rounded = df_pivot.copy()
# ----> 2 df_rounded['gomory_gap'] = (df_rounded['gomory_gap'] * 100).round(2)
#       3 df_rounded['vpc_gap'] = (df_rounded['vpc_gap'] * 100).round(2)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3760, in DataFrame.__getitem__(self, key)
#    3758 if is_single_key:
#    3759     if self.columns.nlevels > 1:
# -> 3760         return self._getitem_multilevel(key)
#    3761     indexer = self.columns.get_loc(key)
#    3762     if is_integer(indexer):
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3815, in DataFrame._getitem_multilevel(self, key)
#    3813 def _getitem_multilevel(self, key):
#    3814     # self.columns is a MultiIndex
# -> 3815     loc = self.columns.get_loc(key)
#    3816     if isinstance(loc, (slice, np.ndarray)):
#    3817         new_columns = self.columns[loc]
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2812, in MultiIndex.get_loc(self, key)
#    2809     return mask
#    2811 if not isinstance(key, tuple):
# -> 2812     loc = self._get_level_indexer(key, level=0)
#    2813     return _maybe_to_slice(loc)
#    2815 keylen = len(key)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/multi.py:3160, in MultiIndex._get_level_indexer(self, key, level, indexer)
#    3157         return slice(i, j, step)
#    3159 else:
# -> 3160     idx = self._get_loc_single_level_index(level_index, key)
#    3162     if level > 0 or self._lexsort_depth == 0:
#    3163         # Desired level is not sorted
#    3164         if isinstance(idx, slice):
#    3165             # test_get_loc_partial_timestamp_multiindex
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/multi.py:2752, in MultiIndex._get_loc_single_level_index(self, level_index, key)
#    2750     return -1
#    2751 else:
# -> 2752     return level_index.get_loc(key)
#
# File /opt/homebrew/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3655, in Index.get_loc(self, key)
#    3653     return self._engine.get_loc(casted_key)
#    3654 except KeyError as err:
# -> 3655     raise KeyError(key) from err
#    3656 except TypeError:
#    3657     # If we have a listlike key, _check_indexing_error will raise
#    3658     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3659     #  the TypeError.
#    3660     self._check_indexing_error(key)
#
# KeyError: 'gomory_gap'

# %%
df_rounded
# Out:
#                               GAP                               TIME           \
# MODE                       gomory           vpc   vpcwsubscip gomory      vpc
# INSTANCE
# 30n20b8              9.682640e-02  0.000000e+00  0.000000e+00  26.99  3657.02
# beasleyC3            1.179610e-02  1.179610e-02  2.811230e-01   0.07   129.94
# binkar10_1           6.759320e-02  6.691340e-02  6.272730e-02   0.09    41.19
# bnatt400             0.000000e+00  0.000000e+00  0.000000e+00   1.93  3531.65
# cod105               8.656170e-03  4.375580e-03  0.000000e+00   4.13   163.12
# cost266-UUE          2.727120e-01  1.863410e-01  2.110370e-01   0.37   298.08
# csched007            8.924880e-02  3.389650e-02  3.227820e-03   0.25   237.80
# exp-1-500-5-5        2.316010e-01  2.173120e-01  2.173120e-01   0.06    36.20
# gen-ip002            2.148250e-02  9.064810e-03  4.108320e-03   0.01     0.17
# glass4               0.000000e+00 -8.881780e-15  0.000000e+00   0.05     2.67
# graph20-20-1rand     0.000000e+00  0.000000e+00  0.000000e+00   0.39     4.53
# graphdraw-domain     1.149490e-03  0.000000e+00  0.000000e+00   0.08     2.63
# icir97_tension       2.015170e-01  2.015170e-01  3.749690e-02   0.47   265.08
# mc11                 4.637900e-03  7.964280e-03  5.085280e-03   0.13  1016.71
# mcsched              4.081780e-04  0.000000e+00  0.000000e+00   1.04  3700.00
# mik-250-20-75-4      5.383000e-01  5.328460e-01  5.328460e-01   0.05     3.26
# milo-v12-6-r2-40-1   0.000000e+00  0.000000e+00  0.000000e+00   0.56  3700.00
# n5-3                 1.525170e-01  1.320470e-01  3.136090e-01   0.14    49.78
# neos-1582420         5.328520e-02  1.845200e-02  0.000000e+00   2.42  2333.74
# neos-3083819-nubu    4.236710e-01  2.312110e-03  1.033400e-02   0.43   120.86
# neos-3216931-puriri  1.684130e-02  0.000000e+00  0.000000e+00  38.83  3700.00
# neos-3381206-awhea   1.554310e-15  0.000000e+00  2.997600e-15   0.16   601.10
# neos-3627168-kasai   1.421100e-01  1.421100e-01  3.510450e-03   0.15   151.74
# neos-911970          1.110220e-16  0.000000e+00  0.000000e+00   0.14    16.13
# neos17               4.778510e-06  0.000000e+00  1.965360e-03   0.08     0.10
# neos5                1.157410e-01  8.333330e-02  8.333330e-02   0.02     0.42
# ns1208400            0.000000e+00  0.000000e+00  0.000000e+00   2.24  2877.51
# ns1830653            1.430070e-01  2.223210e-02  0.000000e+00   1.13    98.72
# nu25-pr12            5.257700e-01  4.432720e-02  3.198260e-01   0.43   222.52
# p200x1188c           4.474480e-03  4.761820e-03  4.761820e-03   0.06     6.74
# pg                   2.429180e-01  2.429880e-01  2.429880e-01   0.07   168.22
# pg5_34               2.344960e-01  2.344960e-01  2.344960e-01   0.08   152.08
# ran14x18-disj-8      2.778530e-03  1.326700e-03  0.000000e+00   0.19    40.99
# reblock115           7.166100e-02  9.966030e-02  1.264510e-01   2.46  2828.68
# rococoC10-001000     2.900880e-01  1.453290e-01  2.569880e-02   0.32   375.33
# roll3000             1.213880e-01  2.480680e-03  3.232820e-04   0.56    95.91
# seymour1             1.346670e-01  1.346570e-01  1.168990e-01   1.10   337.84
# sp150x300d           1.466360e-02  1.097780e-02  1.586750e-01   0.03     2.55
# timtab1              1.255630e-01  1.124410e-01  1.777960e-01   0.03     2.33
# tr12-30             -3.015460e+00 -2.847930e+00 -4.936470e+00   0.08    97.52
# traininstance6       0.000000e+00  0.000000e+00  0.000000e+00   4.94   223.94
# uct-subprob          1.480140e-02  1.470880e-02  9.823220e-03   1.15  2993.58
#
#
# MODE                vpcwsubscip
# INSTANCE
# 30n20b8                 4414.77
# beasleyC3                241.77
# binkar10_1               204.52
# bnatt400                3700.00
# cod105                  3700.00
# cost266-UUE              143.49
# csched007                470.88
# exp-1-500-5-5             28.21
# gen-ip002                  4.42
# glass4                     6.46
# graph20-20-1rand        2813.45
# graphdraw-domain           8.71
# icir97_tension           617.66
# mc11                     932.84
# mcsched                 3700.00
# mik-250-20-75-4            7.45
# milo-v12-6-r2-40-1      3700.00
# n5-3                      48.86
# neos-1582420            3700.00
# neos-3083819-nubu       1350.41
# neos-3216931-puriri     3700.00
# neos-3381206-awhea      1186.53
# neos-3627168-kasai       137.74
# neos-911970               37.63
# neos17                    21.69
# neos5                      5.24
# ns1208400               3700.00
# ns1830653                488.48
# nu25-pr12                177.40
# p200x1188c                 7.82
# pg                        86.09
# pg5_34                    80.72
# ran14x18-disj-8         3700.00
# reblock115              1034.92
# rococoC10-001000         692.32
# roll3000                 472.20
# seymour1                1065.12
# sp150x300d                 8.44
# timtab1                   10.13
# tr12-30                   91.11
# traininstance6          3700.00
# uct-subprob             1078.78
